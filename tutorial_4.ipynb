# %% [markdown]
# # Tutorial 4

# %%
import TemporalDifference

# %% [markdown]
# ## Exercise 5

# %%
TemporalDifference.test_grid_world(TemporalDifference.SARSA, alpha=0.1, gamma=1, epsilon=0.1, num_episodes=1000)
# Out:
# Testing SARSA on Grid-World...
#    0  1  2  3
# 0  G  -  -  -
# 1  -  -  -  -
# 2  -  S  -  -
# 3  -  -  -  G
#
# Performing SARSA...
# Current policy
# o  ←  ←  ↓
# ↑  ↑  →  ↓
# →  ↑  ↓  ↓
# ↓  →  →  o
#
# Performing 1000 test runs ...
# Best reward: -3
# Mean reward: -3.0
# Mean time-step of termination: 2.0
# Rewards: [-100, -85, -13, -21, -22, -19, ..., -3, -3, -5, -3, -4, -3]
# --------------------------------------------------

# %%
TemporalDifference.test_grid_world(TemporalDifference.SARSA, alpha=0.5, gamma=1, epsilon=0.1, num_episodes=1000)
# Out:
# Testing SARSA on Grid-World...
#    0  1  2  3
# 0  G  -  -  -
# 1  -  -  -  -
# 2  -  S  -  -
# 3  -  -  -  G
#
# Performing SARSA...
# Current policy
# o  ←  ←  ↓
# ↑  ↑  ↑  ↓
# ↑  ↑  ↓  ↓
# →  →  →  o
#
# Performing 1000 test runs ...
# Best reward: -3
# Mean reward: -3.0
# Mean time-step of termination: 2.0
# Rewards: [-53, -100, -100, -7, -49, -25, ..., -3, -3, -3, -5, -3, -3]
# --------------------------------------------------

# %%
TemporalDifference.test_grid_world(TemporalDifference.SARSA, alpha=0.4, gamma=0.1, epsilon=0.1, num_episodes=1000)
# Out:
# Testing SARSA on Grid-World...
#    0  1  2  3
# 0  G  -  -  -
# 1  -  -  -  -
# 2  -  S  -  -
# 3  -  -  -  G
#
# Performing SARSA...
# Current policy
# o  ←  ←  ←
# ↑  ←  ↑  ↓
# ↑  ←  →  ↓
# ↑  →  →  o
#
# Performing 1000 test runs ...
# Best reward: -3
# Mean reward: -3.0
# Mean time-step of termination: 2.0
# Rewards: [-100, -100, -100, -100, -26, -3, ..., -3, -3, -3, -3, -3, -3]
# --------------------------------------------------

# %%
TemporalDifference.test_grid_world(TemporalDifference.SARSA, alpha=0.4, gamma=1, epsilon=0.5, num_episodes=1000)
# Out:
# Testing SARSA on Grid-World...
#    0  1  2  3
# 0  G  -  -  -
# 1  -  -  -  -
# 2  -  S  -  -
# 3  -  -  -  G
#
# Performing SARSA...
# Current policy
# o  ←  ←  ←
# ↑  ↑  ←  ↓
# ↑  →  ↓  ↓
# ↑  →  →  o
#
# Performing 1000 test runs ...
# Best reward: -3
# Mean reward: -3.0
# Mean time-step of termination: 2.0
# Rewards: [-90, -16, -21, -3, -18, -11, ..., -3, -3, -5, -3, -7, -5]
# --------------------------------------------------

# %%
TemporalDifference.test_cliff_walking(TemporalDifference.SARSA, alpha=0.4, gamma=1, epsilon=0.1, num_episodes=10000)
# Out:
# Testing SARSA on Cliff-Walking...
#    0  1  2  3  4
# 0  -  -  -  -  -
# 1  S  X  X  X  G
# 2  -  -  -  -  -
# 3  -  -  -  -  -
#
# Performing SARSA...
# 'Q'
# policy
# Current policy
# ↑  →  →  →  ↓
# ↓  ←  ←  ←  o
# ↓  ↓  →  →  ↑
# →  →  →  →  ↑
#
# Performing 1000 test runs ...
# Best reward: -8
# Mean reward: -8.0
# Mean time-step of termination: 7.0
# Rewards: [-694, -595, -199, -892, -2377, -1288, ..., -8, -11, -11, -9, -217, -9]
# --------------------------------------------------

# %%
TemporalDifference.test_cliff_walking(TemporalDifference.SARSA, alpha=0.5, gamma=1, epsilon=0.5, num_episodes=10000)
# Out:
# Testing SARSA on Cliff-Walking...
#    0  1  2  3  4
# 0  -  -  -  -  -
# 1  S  X  X  X  G
# 2  -  -  -  -  -
# 3  -  -  -  -  -
#
# Performing SARSA...
# 'Q'
# policy
# Current policy
# →  →  →  →  ↓
# ↓  ←  ←  ←  o
# ↓  ↓  ↓  →  ↑
# →  →  →  →  ↑
#
# Performing 1000 test runs ...
# Best reward: -8
# Mean reward: -8.0
# Mean time-step of termination: 7.0
# Rewards: [-2773, -7129, -496, -1090, -397, -29, ..., -110, -19, -118, -8, -8, -8]
# --------------------------------------------------

# %%
TemporalDifference.test_cliff_walking(TemporalDifference.SARSA, alpha=0.2, gamma=.5, epsilon=0.1, num_episodes=50000)
# Out:
# Testing SARSA on Cliff-Walking...
#    0  1  2  3  4
# 0  -  -  -  -  -
# 1  S  X  X  X  G
# 2  -  -  -  -  -
# 3  -  -  -  -  -
#
# Performing SARSA...
# 'Q'
# policy
# Current policy
# ←  →  →  →  ↓
# ↓  ←  ←  ←  o
# ↓  ↓  ↓  →  ↑
# →  →  ↓  →  ↑
#
# Performing 1000 test runs ...
# Best reward: -100
# Mean reward: -100.0
# Mean time-step of termination: 99.0
# Rewards: [-3961, -199, -1387, -100, -1090, -260, ..., -9, -8, -421, -132, -31, -229]
# --------------------------------------------------

# %% [markdown]
# Expected SARSA

# %%
TemporalDifference.test_cliff_walking(TemporalDifference.expected_SARSA, alpha=0.3, gamma=.3, epsilon=0.1, num_episodes=10000)
# Out:
# Testing expected_SARSA on Cliff-Walking...
#    0  1  2  3  4
# 0  -  -  -  -  -
# 1  S  X  X  X  G
# 2  -  -  -  -  -
# 3  -  -  -  -  -
#
# Performing Expected-SARSA...
# 'Q'
# policy
# Current policy
# →  →  →  →  ↓
# ↓  ←  ←  ←  o
# →  →  →  →  ↑
# →  →  →  ↑  ↑
#
# Performing 1000 test runs ...
# Best reward: -6
# Mean reward: -6.0
# Mean time-step of termination: 5.0
# Rewards: [-991, -2971, -694, -100, -892, -298, ..., -8, -7, -10, -8, -16, -6]
# --------------------------------------------------

# %%
TemporalDifference.test_cliff_walking(TemporalDifference.expected_SARSA, alpha=0.3, gamma=.3, epsilon=0.3, num_episodes=10000)

# %%
TemporalDifference.test_cliff_walking(TemporalDifference.expected_SARSA, alpha=0.6, gamma=.3, epsilon=0.3, num_episodes=10000)
# Out:
# Testing expected_SARSA on Cliff-Walking...
#    0  1  2  3  4
# 0  -  -  -  -  -
# 1  S  X  X  X  G
# 2  -  -  -  -  -
# 3  -  -  -  -  -
#
# Performing Expected-SARSA...
# 'Q'
# policy
# Current policy
# →  →  →  →  ↓
# ↑  ←  ←  ←  o
# →  →  →  →  ↑
# ↑  ↑  →  →  ↑
#
# Performing 1000 test runs ...
# Best reward: -6
# Mean reward: -6.0
# Mean time-step of termination: 5.0
# Rewards: [-4357, -298, -694, -769, -127, -793, ..., -10, -115, -106, -9, -10, -111]
# --------------------------------------------------

# %% [markdown]
# Q

# %%
TemporalDifference.test_cliff_walking(TemporalDifference.Q_Learning, alpha=0.5, gamma=.5, epsilon=0.2, num_episodes=10000)
# Out:
# Testing Q_Learning on Cliff-Walking...
#    0  1  2  3  4
# 0  -  -  -  -  -
# 1  S  X  X  X  G
# 2  -  -  -  -  -
# 3  -  -  -  -  -
#
# Performing Q-Learning...
# 'Q'
# policy
# Current policy
# →  →  →  →  ↓
# ↓  ←  ←  ←  o
# →  →  →  →  ↑
# →  →  →  →  ↑
#
# Performing 1000 test runs ...
# Best reward: -6
# Mean reward: -6.0
# Mean time-step of termination: 5.0
# Rewards: [-1882, -793, -4357, -199, -397, -275, ..., -10, -14, -107, -8, -6, -106]
# --------------------------------------------------

# %%
TemporalDifference.test_cliff_walking(TemporalDifference.Q_Learning, alpha=0.1, gamma=1, epsilon=0.5, num_episodes=10000)
# Out:
# Testing Q_Learning on Cliff-Walking...
#    0  1  2  3  4
# 0  -  -  -  -  -
# 1  S  X  X  X  G
# 2  -  -  -  -  -
# 3  -  -  -  -  -
#
# Performing Q-Learning...
# 'Q'
# policy
# Current policy
# →  →  →  →  ↓
# ↓  ←  ←  ←  o
# →  →  →  →  ↑
# →  →  →  →  ↑
#
# Performing 1000 test runs ...
# Best reward: -6
# Mean reward: -6.0
# Mean time-step of termination: 5.0
# Rewards: [-1585, -496, -199, -397, -100, -6, ..., -110, -8, -112, -210, -6, -110]
# --------------------------------------------------

# %% [markdown]
# Double Q

# %%
TemporalDifference.test_cliff_walking(TemporalDifference.Double_Q_Learning, alpha=0.5, gamma=1, epsilon=0.5, num_episodes=10000)
# Out:
# Testing Double_Q_Learning on Cliff-Walking...
#    0  1  2  3  4
# 0  -  -  -  -  -
# 1  S  X  X  X  G
# 2  -  -  -  -  -
# 3  -  -  -  -  -
#
# Performing Double-Q-Learning...
# 'Q'
# policy
# Current policy
# →  →  →  →  ↓
# ↑  ←  ←  ←  o
# →  →  →  →  ↑
# →  →  →  →  ↑
#
# Performing 1000 test runs ...
# Best reward: -6
# Mean reward: -6.0
# Mean time-step of termination: 5.0
# Rewards: [-4555, -595, -1288, -793, -496, -100, ..., -106, -6, -221, -8, -6, -8]
# --------------------------------------------------

# %%
TemporalDifference.test_cliff_walking(TemporalDifference.Double_Q_Learning, alpha=0.5, gamma=1, epsilon=0.5, num_episodes=10000)
# Out:
# Testing Double_Q_Learning on Cliff-Walking...
#    0  1  2  3  4
# 0  -  -  -  -  -
# 1  S  X  X  X  G
# 2  -  -  -  -  -
# 3  -  -  -  -  -
#
# Performing Double-Q-Learning...
# 'Q'
# policy
# Current policy
# ←  ←  →  →  ↓
# ↓  ←  ←  ←  o
# →  →  →  →  ↑
# →  →  →  →  ↑
#
# Performing 1000 test runs ...
# Best reward: -6
# Mean reward: -6.0
# Mean time-step of termination: 5.0
# Rewards: [-4258, -100, -199, -595, -595, -990, ..., -6, -326, -6, -112, -8, -109]
# --------------------------------------------------

# %%
TemporalDifference.test_cliff_walking(TemporalDifference.Double_Q_Learning, alpha=0.3, gamma=.3, epsilon=0.1, num_episodes=10000)
# Out:
# Testing Double_Q_Learning on Cliff-Walking...
#    0  1  2  3  4
# 0  -  -  -  -  -
# 1  S  X  X  X  G
# 2  -  -  -  -  -
# 3  -  -  -  -  -
#
# Performing Double-Q-Learning...
# 'Q'
# policy
# Current policy
# →  →  →  →  ↓
# ↓  ←  ←  ←  o
# →  →  →  →  ↑
# →  →  →  →  ↑
#
# Performing 1000 test runs ...
# Best reward: -6
# Mean reward: -6.0
# Mean time-step of termination: 5.0
# Rewards: [-4159, -298, -397, -213, -298, -298, ..., -9, -9, -315, -12, -411, -8]
# --------------------------------------------------

# %%
TemporalDifference.test_cliff_walking(TemporalDifference.Double_Q_Learning, alpha=0.3, gamma=.3, epsilon=1, num_episodes=10000)
# Out:
# Testing Double_Q_Learning on Cliff-Walking...
#    0  1  2  3  4
# 0  -  -  -  -  -
# 1  S  X  X  X  G
# 2  -  -  -  -  -
# 3  -  -  -  -  -
#
# Performing Double-Q-Learning...
# 'Q'
# policy
# Current policy
# ←  ←  ←  ←  ↓
# ↓  ←  ←  ←  o
# →  →  →  →  ↑
# →  →  →  →  ↑
#
# Performing 1000 test runs ...
# Best reward: -6
# Mean reward: -6.0
# Mean time-step of termination: 5.0
# Rewards: [-1783, -4555, -298, -1981, -595, -496, ..., -6, -6, -8, -114, -7, -6]
# --------------------------------------------------

# %% [markdown]
# Speedy Q

# %%
TemporalDifference.test_cliff_walking(TemporalDifference.Speedy_Q_Learning, alpha=0.6, gamma=.3, epsilon=0.1, num_episodes=10000)
# Out:
# Testing Speedy_Q_Learning on Cliff-Walking...
#    0  1  2  3  4
# 0  -  -  -  -  -
# 1  S  X  X  X  G
# 2  -  -  -  -  -
# 3  -  -  -  -  -
#
# Performing Speedy-Q-Learning...
# 'Q'
# policy
# Current policy
# ←  ↑  ↑  ↑  ↓
# ↓  ←  ←  ←  o
# ←  ←  →  →  ↑
# ←  ←  ←  ←  ←
#
# Performing 1000 test runs ...
# Best reward: -100
# Mean reward: -100.0
# Mean time-step of termination: 99.0
# Rewards: [-2575, -496, -892, -694, -991, -571, ..., -595, -199, -11, -236, -595, -100]
# --------------------------------------------------

# %%
TemporalDifference.test_cliff_walking(TemporalDifference.Speedy_Q_Learning, alpha=0.6, gamma=.3, epsilon=0.4, num_episodes=10000)
# Out:
# Testing Speedy_Q_Learning on Cliff-Walking...
#    0  1  2  3  4
# 0  -  -  -  -  -
# 1  S  X  X  X  G
# 2  -  -  -  -  -
# 3  -  -  -  -  -
#
# Performing Speedy-Q-Learning...
# 'Q'
# policy
# Current policy
# ←  ↑  ↑  ↑  ↓
# ↓  ←  ←  ←  o
# ←  ←  ↓  ↓  ↑
# ←  ↓  ↓  ↓  ↑
#
# Performing 1000 test runs ...
# Best reward: -100
# Mean reward: -100.0
# Mean time-step of termination: 99.0
# Rewards: [-3268, -298, -397, -298, -1090, -18, ..., -186, -44, -298, -892, -1585, -130]
# --------------------------------------------------

# %%
TemporalDifference.test_cliff_walking(TemporalDifference.Speedy_Q_Learning, alpha=0.6, gamma=1, epsilon=0.1, num_episodes=10000)
# Out:
# Testing Speedy_Q_Learning on Cliff-Walking...
#    0  1  2  3  4
# 0  -  -  -  -  -
# 1  S  X  X  X  G
# 2  -  -  -  -  -
# 3  -  -  -  -  -
#
# Performing Speedy-Q-Learning...
# 'Q'
# policy
# Current policy
# ←  ↑  ↑  ↑  ↓
# ↓  ←  ←  ←  o
# ←  ←  ↓  →  ↑
# ←  ↓  →  →  →
#
# Performing 1000 test runs ...
# Best reward: -100
# Mean reward: -100.0
# Mean time-step of termination: 99.0
# Rewards: [-496, -397, -991, -496, -158, -694, ..., -397, -595, -44, -53, -1585, -40]
# --------------------------------------------------
